# %% [markdown]
# ##練習 I

# %%
friends = ["Tom", "John", "Mary", "Jane"]

# %%
L = []

# %%
for i in range(len(students)):
    message = "HI %s,would you like to have a dinner together?" % friends[i]
    L.append(message)

# %%
L
# Out:
# ['HI Tom,would you like to have a dinner together?',
#  'HI John,would you like to have a dinner together?',
#  'HI Mary,would you like to have a dinner together?',
#  'HI Jane,would you like to have a dinner together?']

# %% [markdown]
# ##練習 II

# %%
import pandas as pd

# %%
df = pd.read_csv("grades.csv")

# %%
df.head()
# Out:
#     姓名  國文  英文  數學  自然  社會
# 0  劉俊安   9  10  15  10  13
# 1  胡玉華  10  10  10   8   9
# 2  黃淑婷  13  15   8  11  14
# 3  陳上紫  10  10   8   9  14
# 4  崔靜成  13  12  14  12  13

# %%
df["總級分"] = df.sum(1)

# %%
df["平均級分"] = df["總級分"]/5

# %%
df.head(10)
# Out:
#     姓名  國文  英文  數學  自然  社會  總級分  平均級分
# 0  劉俊安   9  10  15  10  13   57  11.4
# 1  胡玉華  10  10  10   8   9   47   9.4
# 2  黃淑婷  13  15   8  11  14   61  12.2
# 3  陳上紫  10  10   8   9  14   51  10.2
# 4  崔靜成  13  12  14  12  13   64  12.8
# 5  張雅岳  13  12  12  12   8   57  11.4
# 6  梁俊翔  11  13  10  10  14   58  11.6
# 7  林金鳳   8   9  10  10   8   45   9.0
# 8  許協旺   9   9  12  10  10   50  10.0
# 9  郭雅惠  10  15  12  11   9   57  11.4

# %% [markdown]
# ##練習 III

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
A = pd.DataFrame(randint(5,100,(10,4)),
                 columns = ['姓名','微積分','線性代數','數值分析'])

# %%
A.head(10)
# Out:
#    姓名  微積分  線性代數  數值分析
# 0  30   48    19    83
# 1  89   86    98    69
# 2  88   61     5    82
# 3  40   35    33    49
# 4  65   17    66    23
# 5  98   82    72    64
# 6  41   83    30    37
# 7  80   52    42    29
# 8  43   39    55    31
# 9  52   32    79    73

# %%
N = ['陳勝孝','王芳屏','吳柏美','李蘭姍','葉惟慈','曹柏勳','楊俊賢','鄭吉新','阮嘉中','郭智鈞']

# %%
A['姓名'] = N

# %%
A.head(10)
# Out:
#     姓名  微積分  線性代數  數值分析
# 0  陳勝孝   48    19    83
# 1  王芳屏   86    98    69
# 2  吳柏美   61     5    82
# 3  李蘭姍   35    33    49
# 4  葉惟慈   17    66    23
# 5  曹柏勳   82    72    64
# 6  楊俊賢   83    30    37
# 7  鄭吉新   52    42    29
# 8  阮嘉中   39    55    31
# 9  郭智鈞   32    79    73

# %%
A.to_csv("math_grades.csv",index=False,header=header)

# %%
B = pd.read_csv("math_grades.csv")

# %%
B
# Out:
#     姓名  微積分  線性代數  數值分析
# 0  陳勝孝   48    19    83
# 1  王芳屏   86    98    69
# 2  吳柏美   61     5    82
# 3  李蘭姍   35    33    49
# 4  葉惟慈   17    66    23
# 5  曹柏勳   82    72    64
# 6  楊俊賢   83    30    37
# 7  鄭吉新   52    42    29
# 8  阮嘉中   39    55    31
# 9  郭智鈞   32    79    73
